# %%
import tensorflow
import numpy
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras import preprocessing
from tensorflow.keras.layers import  Embedding, Dense, Flatten, LSTM, Dropout, BatchNormalization, Bidirectional, Conv1D, MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import io
import json
import os

# %%
samples = []
ids = []
with open('train.txt') as text:
    inc = 0
    lines = text.readlines()
    lines = list(dict.fromkeys(lines))
    for line in lines:
        inc = inc + 1
        if inc == 20000:
            break
        #print(line.split('\\'))
        splittedLines = line.split('\\')
        if len(splittedLines) != 1 and splittedLines[0] != 'TradeBot':
            samples.append(splittedLines[1])
            ids.append(''.join(e for e in splittedLines[0] if e.isalnum()))

# %%
len(samples)
# Out:
# 19613

# %%
len(ids)
# Out:
# 19613

# %%
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(samples)
tokenizerForNames = Tokenizer(num_words=1000)
tokenizerForNames.fit_on_texts(ids)

# saving
tokenizer_json = tokenizer.to_json()
with io.open('tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))

tokenizerForNames_json = tokenizerForNames.to_json()
with io.open('tokenizerForNames.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizerForNames_json, ensure_ascii=False))

# %%
sequences = tokenizer.texts_to_sequences(samples)
tokenizedNames = tokenizerForNames.texts_to_sequences(numpy.asarray(ids))
len(sequences) - len(tokenizedNames)
# Out:
# 0

# %%
x_train = preprocessing.sequence.pad_sequences(sequences, maxlen=40)
y_train = to_categorical(tokenizedNames, dtype=int);
print(len(x_train))
print(len(x_train) - len(y_train))
# Out:
# 19613
# 0

# %%
x_train.shape
y_train[:,1:].shape[1]
# Out:
# 57

# %%
model = Sequential()
model.add(Embedding(10000, 64,input_length=40))
model.add(Conv1D(32, 8, activation='relu'))
model.add(MaxPooling1D(5))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(LSTM(64, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(LSTM(64, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(100, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(y_train[:,1:].shape[1], activation='softmax'))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
metrics=['acc']
model.summary()

checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tensorflow.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 40, 64)            640000
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 33, 32)            16416
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 6, 32)             0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 32)             128
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 6, 32)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 6, 128)            49664
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 6, 128)            512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 128)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 6, 64)             49408
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 6, 64)             256
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 6, 64)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 6, 64)             33024
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 6, 64)             256
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 64)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6, 100)            6500
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 6, 100)            400
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 6, 100)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 600)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 57)                34257
# =================================================================
# Total params: 830,821
# Trainable params: 830,045
# Non-trainable params: 776
# _________________________________________________________________

# %%
history = model.fit(x_train,
                    y_train[:,1:],
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2,
                    callbacks=[cp_callback])
# Out:
# Epoch 1/10
# 490/491 [============================>.] - ETA: 0s - loss: 3.2118
# Epoch 00001: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 14s 29ms/step - loss: 3.2113 - val_loss: 3.0740
# Epoch 2/10
#  - ETA: 1s - loss: 2.9110
# Epoch 00002: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.9014 - val_loss: 3.3100
# Epoch 3/10
#  - ETA: 5s - loss: 2.8349
# Epoch 00003: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.8228 - val_loss: 3.0902
# Epoch 4/10
# 489/491 [============================>.] - ETA: 0s - loss: 2.7847
# Epoch 00004: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 24ms/step - loss: 2.7843 - val_loss: 3.0340
# Epoch 5/10
# 489/491 [============================>.] - ETA: 0s - loss: 2.7621
# Epoch 00005: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.7620 - val_loss: 2.9124
# Epoch 6/10
#  - ETA: 0s - loss: 2.7371
# Epoch 00006: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.7363 - val_loss: 3.6160
# Epoch 7/10
# 489/491 [============================>.] - ETA: 0s - loss: 2.7152
# Epoch 00007: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.7146 - val_loss: 3.2842
# Epoch 8/10
#  - ETA: 10s - loss: 2.6656
# Epoch 00008: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 13s 26ms/step - loss: 2.6887 - val_loss: 3.0885
# Epoch 9/10
# 489/491 [============================>.] - ETA: 0s - loss: 2.6608
# Epoch 00009: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 13s 26ms/step - loss: 2.6612 - val_loss: 3.5509
# Epoch 10/10
# 489/491 [============================>.] - ETA: 0s - loss: 2.6313
# Epoch 00010: saving model to training_1\cp.ckpt
# 491/491 [==============================] - 12s 25ms/step - loss: 2.6306 - val_loss: 3.1559

# %%
numpy.transpose([tokenizedNames,ids])
# Out:
# array([[list([2]), 'Giallar'],
#        [list([6]), 'TBPSS'],
#        [list([6]), 'TBPSS'],
#        ...,
#        [list([2]), 'Giallar'],
#        [list([1]), 'nnnn1111'],
#        [list([1]), 'nnnn1111']], dtype=object)

# %%
model.predict(x_train)
# Out:
# array([[1.30268678e-01, 1.59834355e-01, 1.46082804e-01, ...,
#         7.94296328e-04, 4.03043145e-04, 4.17473639e-04],
#        [1.21235862e-01, 1.53325483e-01, 1.19691685e-01, ...,
#         8.48133350e-04, 5.48269076e-04, 5.14014275e-04],
#        [1.21235862e-01, 1.53325483e-01, 1.19691685e-01, ...,
#         8.48133350e-04, 5.48269076e-04, 5.14014275e-04],
#        ...,
#        [1.21920735e-01, 1.08901031e-01, 1.56914830e-01, ...,
#         8.43893096e-04, 4.26757295e-04, 4.41761833e-04],
#        [6.69955373e-01, 3.61766405e-02, 1.59100667e-01, ...,
#         3.13478144e-04, 1.75582449e-04, 1.80902425e-04],
#        [6.69955373e-01, 3.61766405e-02, 1.59100667e-01, ...,
#         3.13478144e-04, 1.75582449e-04, 1.80902425e-04]], dtype=float32)

# %%
output = numpy.asarray(list(map(numpy.argmax, model.predict(x_train)))).reshape(len(x_train),1)
print(output)
# Out:
# [[3]
#  [1]
#  [1]
#  ...
#  [3]
#  [0]
#  [0]]

# %%
tokenizerForNames.sequences_to_texts(output + 1)
# Out:
# ['penspam',
#  'giallar',
#  'giallar',
#  'kolm5',
#  'kolm5',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'penspam',
#  'nnnn1111',
#  'tbpss',
#  'nnnn1111',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'kolm5',
#  'tbpss',
#  'giallar',
#  'tbpss',
#  'nnnn1111',
#  'giallar',
#  'byfreeze',
#  'giallar',
#  'tbpss',
#  'giallar',
#  'nnnn1111',
#  'byfreeze',
#  'tbpss',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'tbpss',
#  'nnnn1111',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'tbpss',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'byfreeze',
#  'tbpss',
#  'byfreeze',
#  'nnnn1111',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'giallar',
#  'byfreeze',
#  'gormengast',
#  'kolm5',
#  'tbpss',
#  'tbpss',
#  'giallar',
#  'tbpss',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'дмитро',
#  'дмитро',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'gormengast',
#  'gormengast',
#  'diktutor',
#  'diktutor',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'tbpss',
#  'tbpss',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'lazerbeard',
#  'lazerbeard',
#  'lazerbeard',
#  'lazerbeard',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpss',
#  'tbpss',
#  'nnnn1111',
#  'nnnn1111',
#  'tbpsstest',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'tbpsstest',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'penspam',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'tbpsstest',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'nnnn1111',
#  'tezzar',
#  'tezzar',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'penspam',
#  'tezzar',
#  'tezzar',
#  'giallar',
#  'giallar',
#  'kolm5',
#  'kolm5',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'tbpsstest',
#  'tbpsstest',
#  'tezzar',
#  'tezzar',
#  'penspam',
#  'penspam',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'penspam',
#  'kolm5',
#  'kolm5',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'penspam',
#  'penspam',
#  'lazerbeard',
#  'lazerbeard',
#  'tbpsstest',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'gormengast',
#  'gormengast',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'giallar',
#  'giallar',
#  'gormengast',
#  'gormengast',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'nnnn1111',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'kolm5',
#  'kolm5',
#  'tbpsstest',
#  'tbpsstest',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'tbpss',
#  'tbpss',
#  'gormengast',
#  'gormengast',
#  'tbpss',
#  'tbpss',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'nnnn1111',
#  'nnnn1111',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'gormengast',
#  'gormengast',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'gormengast',
#  'gormengast',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'tbpss',
#  'happy',
#  'happy',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'kolm5',
#  'kolm5',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'tbpss',
#  'tbpss',
#  'gormengast',
#  'gormengast',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'tbpss',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'byfreeze',
#  'byfreeze',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'gormengast',
#  'gormengast',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'penspam',
#  'penspam',
#  'penspam',
#  'penspam',
#  'tbpss',
#  'tbpss',
#  'kolm5',
#  'kolm5',
#  'дмитро',
#  'дмитро',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'kolm5',
#  'kolm5',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'дмитро',
#  'дмитро',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'kolm5',
#  'kolm5',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'дмитро',
#  'дмитро',
#  'kolm5',
#  'kolm5',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'byfreeze',
#  'byfreeze',
#  'gormengast',
#  'gormengast',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'tbpss',
#  'tbpss',
#  'дмитро',
#  'дмитро',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'kolm5',
#  'kolm5',
#  'nnnn1111',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'kolm5',
#  'kolm5',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'byfreeze',
#  'byfreeze',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'tezzar',
#  'tezzar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'tbpss',
#  'tbpss',
#  'byfreeze',
#  'byfreeze',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'nnnn1111',
#  'nnnn1111',
#  'giallar',
#  'giallar',
#  'giallar',
#  'giallar',
#  'penspam',
#  'giallar',
#  'giallar',
#  'tezzar',
#  'tezzar',
#  'byfreeze',
#  'byfreeze',
#  ...]

# %%
tokenizerForNames.sequences_to_texts([[1]])
# Out:
# ['nnnn1111']
